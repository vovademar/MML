# %% [markdown]
# # Специализированные программные библиотеки для анализа данных.

# %% [markdown]
# ## Медведев Вальдемар Сергеевич 20214

# %% [markdown]
# ### Импортируем необходимые модули

# %%
import numpy as np
import pandas as pd
import datetime

# %% [markdown]
# ### Ваш набор данных - сводка по эпидемиологической обстановке в России. В этом домашнем задании 6 пунктов, постарайтесь выполнить их все. Всего за эту домашку можно получить 8 баллов.

# %% [markdown]
# ### 1. Препроцессинг данных (2 балла)
#
# Подготовьте данные для анализа. Загрузите файлы COVID_RU_Ya_stat_2022.csv и COVID_RU_Ya_descr.csv, объедините эти две таблицы в одну. Преобразуйте тип данных в колонке "Дата" к типу "datetime64" и введите двойной индекс на основе колонок "Регион" и "Дата". Добавьте в вашу таблицу новые колонки. Отсортируйте таблицу по индексам. Выведите 5 первых строчек получившейся таблицы.

# %%
## прочитайте данные из файла 'COVID_RU_Ya_descr.csv'
# ncov_ru_de = **YOUR CODE HERE**
## прочитайте данные из файла 'COVID_RU_Ya_stat_2022.csv'
# ncov_ru_stat = **YOUR CODE HERE**

# %%
ncov_ru_de = pd.read_csv('./Вальдемар Сергеевич Медведев - COVID_RU_Ya_descr.csv')
ncov_ru_stat = pd.read_csv('./Вальдемар Сергеевич Медведев - COVID_RU_Ya_stat_2022.csv')

# %%
ncov_ru_de
# Out:
#     Unnamed: 0                                 ФО              Регион  \
# 0            0  Дальневосточный федеральный округ       Амурская обл.
# 1            1  Дальневосточный федеральный округ             Бурятия
# 2            2  Дальневосточный федеральный округ        Еврейская АО
# 3            3  Дальневосточный федеральный округ  Забайкальский край
# 4            4  Дальневосточный федеральный округ     Камчатский край
# ..         ...                                ...                 ...
# 80          80            Южный федеральный округ     Ростовская обл.
# 81          81            Южный федеральный округ         Севастополь
# 82         420  Дальневосточный федеральный округ        Чукотский АО
# 83         442  Северо-Западный федеральный округ         Ненецкий АО
# 84         621        Сибирский федеральный округ               Алтай
#
#                  Регион название  Регион население
# 0               Амурская область            798424
# 1             Республика Бурятия            984511
# 2   Еврейская автономная область            162014
# 3             Забайкальский край           1072806
# 4                Камчатский край            315557
# ..                           ...               ...
# 80            Ростовская область           4220452
# 81                   Севастополь            436670
# 82    Чукотский автономный округ             49348
# 83     Ненецкий автономный округ             43997
# 84              Республика Алтай            218063
#
# [85 rows x 5 columns]

# %%
ncov_ru_stat
# Out:
#        Unnamed: 0        Дата             Регион  Заражений  Выздоровлений  \
# 0               0  20.10.2020      Пермский край      11862           7993
# 1               1  29.12.2021          Татарстан      42537          36175
# 2               2  23.01.2021           Марий Эл      10309           8980
# 3               3  14.05.2021  Красноярский край      71858          66180
# 4               4  12.04.2022               Крым     180027         172186
# ...           ...         ...                ...        ...            ...
# 79453       79453  10.01.2021   Кемеровская обл.      27032          24221
# 79454       79454  03.07.2021    Смоленская обл.      35314          31844
# 79455       79455  16.12.2020   Ульяновская обл.      32062          29113
# 79456       79456  26.11.2020  Свердловская обл.      44775          36975
# 79457       79457  01.04.2021     Самарская обл.      55930          52644
#
#        Смертей  Смертей за день  Заражений за день  Выздоровлений за день  \
# 0          355                5                128                     81
# 1         1425                5                 80                    100
# 2          147                0                 46                     56
# 3         3628                8                102                     90
# 4         5158                6                141                    157
# ...        ...              ...                ...                    ...
# 79453      488                1                116                    105
# 79454     1133                8                257                     93
# 79455      415                0                289                    324
# 79456      988                8                391                    395
# 79457     1107                9                199                    201
#
#        Летальность, %
# 0                2.99
# 1                3.35
# 2                1.43
# 3                5.05
# 4                2.87
# ...               ...
# 79453            1.81
# 79454            3.21
# 79455            1.29
# 79456            2.21
# 79457            1.98
#
# [79458 rows x 10 columns]

# %%
## объедените таблицы ncov_ru_de и ncov_ru_stat -- необходимо использовать какой-то ключ для объединения 
## и что это за поле могло бы быть ключом?

# ncov_ru_j = **YOUR CODE HERE**

# %%
ncov_ru_j = ncov_ru_de.merge(ncov_ru_stat, on='Регион')

# %%
## так можно посмотреть колонки:
#ncov_ru_de.columns
#ncov_ru_stat.columns
## так можно посмотреть индексы:
#  ncov_ru_de.index
#  ncov_ru_stat.index

## преобразуйте тип данных в колонке "Дата" к типу "datetime64" -- примеры в нашем занятии
## задайте в вашей таблице индексацию по полям "Регион" и "Дата"

ncov_ru_j.loc[:, 'Дата'] = ncov_ru_j['Дата'].astype('datetime64')
# Out:
# /tmp/ipykernel_68253/4210564391.py:11: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   ncov_ru_j.loc[:, 'Дата'] = ncov_ru_j['Дата'].astype('datetime64')
# /tmp/ipykernel_68253/4210564391.py:11: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ncov_ru_j.loc[:, 'Дата'] = ncov_ru_j['Дата'].astype('datetime64')

# %%
ncov_ru_j.set_index(['Регион','Дата'], inplace = True)

# %%
df = ncov_ru_j.sort_index().head()

# %%
## Создайте в вашей таблице колонки:
# "Активных" - число активных случаев = 'Заражений' - 'Выздоровлений' - 'Смертей'
# "Активных на 100К населения"
# "Заражений на 100К населения"
# "Смертей на 100К населения"
# "Заражений за день на 100К населения"
# "Смертей за день на 100К населения"

# %%
df = df.assign(Активных = df.Заражений + df.Выздоровлений + df.Смертей)
df = df.assign(Активных_на_100к = (df.Заражений + df.Выздоровлений + df.Смертей)/100000)
df = df.assign(Заражений_на_100_к = df.Заражений / 100000)
df = df.assign(Смертей_на_100_к = df.Смертей / 100000)
df = df.assign(Заражений_за_день_на_100_к = df['Заражений за день'] / 100000)
df = df.assign(Смертей_за_день_на_100к = df['Смертей за день'] / 100000)

df
# Out:
#                    Unnamed: 0_x                       ФО    Регион название  \
# Регион Дата
# Адыгея 2020-01-04            74  Южный федеральный округ  Республика Адыгея
#        2020-01-05            74  Южный федеральный округ  Республика Адыгея
#        2020-01-06            74  Южный федеральный округ  Республика Адыгея
#        2020-01-07            74  Южный федеральный округ  Республика Адыгея
#        2020-01-08            74  Южный федеральный округ  Республика Адыгея
#
#                    Регион население  Unnamed: 0_y  Заражений  Выздоровлений  \
# Регион Дата
# Адыгея 2020-01-04            453376         76910          4              0
#        2020-01-05            453376         63880        165             48
#        2020-01-06            453376         54163        874            394
#        2020-01-07            453376         67289       1935           1340
#        2020-01-08            453376         37734       2775           2130
#
#                    Смертей  Смертей за день  Заражений за день  \
# Регион Дата
# Адыгея 2020-01-04        0                0                  0
#        2020-01-05        3                0                  2
#        2020-01-06        9                0                 20
#        2020-01-07       14                0                 37
#        2020-01-08       20                0                 28
#
#                    Выздоровлений за день  Летальность, %  Активных  \
# Регион Дата
# Адыгея 2020-01-04                      0            0.00         4
#        2020-01-05                      0            1.82       216
#        2020-01-06                     23            1.03      1277
#        2020-01-07                     38            0.72      3289
#        2020-01-08                     18            0.72      4925
#
#                    Активных_на_100к  Заражений_на_100_к  Смертей_на_100_к  \
# Регион Дата
# Адыгея 2020-01-04           0.00004             0.00004           0.00000
#        2020-01-05           0.00216             0.00165           0.00003
#        2020-01-06           0.01277             0.00874           0.00009
#        2020-01-07           0.03289             0.01935           0.00014
#        2020-01-08           0.04925             0.02775           0.00020
#
#                    Заражений_за_день_на_100_к  Смертей_за_день_на_100к
# Регион Дата
# Адыгея 2020-01-04                     0.00000                      0.0
#        2020-01-05                     0.00002                      0.0
#        2020-01-06                     0.00020                      0.0
#        2020-01-07                     0.00037                      0.0
#        2020-01-08                     0.00028                      0.0

# %% [markdown]
# ### 2. Подсчёт численности населения (1 балл)
#
# Посчитайте численность населения в федеральных округах и в РФ.

# %%
# **YOUR CODE HERE**
regions = ncov_ru_de[['ФО','Регион население']].groupby('ФО').agg(['sum'])
regions
# Out:
#                                     Регион население
#                                                  sum
# ФО
# Дальневосточный федеральный округ            8222601
# Приволжский федеральный округ               29542696
# Северо-Западный федеральный округ           13952003
# Северо-Кавказский федеральный округ          9823481
# Сибирский федеральный округ                 17230157
# Уральский федеральный округ                 12356229
# Центральный федеральный округ               39311413
# Южный федеральный округ                     16441852

# %% [markdown]
# Население РФ

# %%
regions.sum()
# Out:
# Регион население  sum    146880432
# dtype: int64

# %% [markdown]
# ### 3. Летальность в регионах (1 балл)
#
# Cравните регионы по уровню летальности за 2020-06-11. Нужно представить ответ в 3 клетках:
#
#     1. Выведите 10 регионов с наибольшей летальностью
#     2. Выведите 10 регионов с наименьшей летальностью
#     3. Опишите летальность за 2020-06-11 через среднее, квантили, мин., макс. и т.д.
#
# Подсказка: вы можете отсортировать значения в таблице с помощью функции `sort_values()` (в ней также можно менять порядок сортировки), а извлечение конкретных значений (в вашем случае, определенной даты) в таблице с мультииндексацией производится с помощью метода `ncov_ru_j.xs(...)`

# %%
## сортировка значений производится с помощью метода ncov_ru_j.xs(<ваше творчество>)['Летальность, %'].sort_values(ascending = False)

ncov_ru_j.xs('2020-06-11', level = 'Дата')['Летальность, %'].sort_values(ascending = False).head(10)
# Out:
# Регион
# Санкт-Петербург       6.05
# Дагестан              4.82
# Новосибирская обл.    3.33
# Тульская обл.         3.30
# Тверская обл.         3.20
# Пермский край         2.91
# Ростовская обл.       2.80
# Владимирская обл.     2.68
# Севастополь           2.64
# Омская обл.           2.55
# Name: Летальность, %, dtype: float64

# %%
ncov_ru_j.xs('2020-06-11', level = 'Дата')['Летальность, %'].sort_values(ascending = True).head(10)
# Out:
# Регион
# Ненецкий АО            0.00
# Сахалинская обл.       0.05
# Алтай                  0.24
# Карачаево-Черкессия    0.34
# Белгородская обл.      0.50
# Башкортостан           0.51
# Тамбовская обл.        0.53
# Брянская обл.          0.54
# Ярославская обл.       0.56
# Рязанская обл.         0.58
# Name: Летальность, %, dtype: float64

# %%
# **YOUR CODE HERE**

# %%
a = ncov_ru_j.xs('2020-06-11', level = 'Дата')
#a.groupby('Летальность, %').agg(['min', 'max', 'mean','median', 'sum'])
#a = a.assign(min = a['Летальность, %'])
a = a.groupby('Летальность, %').agg(['min'])
a
#a[['min', 'max', 'mean','median']]
#a[['Летальность, %']]
# Out:
#                Unnamed: 0_x                                   ФО  \
#                         min                                  min
# Летальность, %
# 0.00                    442    Северо-Западный федеральный округ
# 0.05                      8    Дальневосточный федеральный округ
# 0.24                    621          Сибирский федеральный округ
# 0.34                     37  Северо-Кавказский федеральный округ
# 0.50                     56        Центральный федеральный округ
# ...                     ...                                  ...
# 3.20                     71        Центральный федеральный округ
# 3.30                     72        Центральный федеральный округ
# 3.33                     45          Сибирский федеральный округ
# 4.82                     34  Северо-Кавказский федеральный округ
# 6.05                     33    Северо-Западный федеральный округ
#
#                                 Регион название Регион население Unnamed: 0_y  \
#                                             min              min          min
# Летальность, %
# 0.00                  Ненецкий автономный округ            43997        34153
# 0.05                        Сахалинская область           490181         1387
# 0.24                           Республика Алтай           218063        46414
# 0.34            Карачаево-Черкесская Республика           466305        57837
# 0.50                       Белгородская область          1549876        78106
# ...                                         ...              ...          ...
# 3.20                           Тверская область          1283873        12811
# 3.30                           Тульская область          1491855        28722
# 3.33                      Новосибирская область          2788849        43413
# 4.82                        Республика Дагестан          3063885         7894
# 6.05                            Санкт-Петербург          5351935        31025
#
#                Заражений Выздоровлений Смертей Смертей за день  \
#                      min           min     min             min
# Летальность, %
# 0.00                 507           184       0               0
# 0.05                8426          5742       4               1
# 0.24                8438          5738      20               0
# 0.34               10117          6031      34               0
# 0.50               12306         10644      61               0
# ...                  ...           ...     ...             ...
# 3.20               10547          6150     338               3
# 3.30               13141         11260     433               2
# 3.33               18381         15124     612               3
# 4.82               16570         14881     799               8
# 6.05               67434         41533    4078              54
#
#                Заражений за день Выздоровлений за день
#                              min                   min
# Летальность, %
# 0.00                           7                     0
# 0.05                         102                    89
# 0.24                         163                   171
# 0.34                          84                    84
# 0.50                         142                   150
# ...                          ...                   ...
# 3.20                         171                   120
# 3.30                         130                    82
# 3.33                         176                   171
# 4.82                          91                    82
# 6.05                        1171                   563
#
# [70 rows x 11 columns]

# %% [markdown]
# ### 4. Летальность в федеральных округах (2 балла)
#
# Рассчитайте летальность по федеральным округам по формуле: "Смертей" * 100 / "Заражений". Преобразуйте таблицу к следующему виду: округа (строки) х дата (столбцы). Оставьте только последние 14 дней и сохраните получившуюся таблицу в формате csv. Выведите, какой округ лидирует по уровню летальности, в отдельной клетке.

# %%
# **YOUR CODE HERE**

# %% [markdown]
# ### 5. Статистика по активным случаям в федеральных округах (1 балл)
#
# Постройте сводную таблицу (с помощью pd.pivot_table) с данными о среднем, минимальном и максимальном количестве активных случаев на 100 тыс. человек за сентябрь 2022 г. по федеральным округам.
#
# Подсказка: вам придется прибегнуть к условной индексации по полю "Дата"  в формате datetime, сделать это можно через вызов dt: к примеру, `ncov_ru_j.reset_index()["Дата"].dt.month == 9` проверяет соответствие месяца в дате сентябрю. Не забудьте также проверить нужный год.

# %%
# **YOUR CODE HERE**

# %% [markdown]
# ### 6. Наименьшая заболеваемость в регионах (1 балл)
#
# Выведите 10 регионов с наименьшей заболеваемостью на 2022-09-30 (по колонке "Заражений на 100К населения").

# %%
# **YOUR CODE HERE**

# %%
## Следующее ДЗ тоже будет по этим данным -- будем рисовать красивые графики

# %%
## это -- для напоминания о том, как усреднять по заданному скользящему окну
## и как получать простые графики
## ncov_ru.loc[['Москва',]]['Активных'].unstack().T.rolling(7).mean().plot()

# %% [markdown]
# Домашнее задание сдаем в виде ноутбука *.ipynb -- можно расшарить ноутбук в Colab'е.
# Обязательно указываем ФИО
# Вопросы категорически приветствуются.
